# %%
import requests

# Go to https://www.yelp.com/developers/
# create an app, and get the key
key = 'iI4dsdXt-g13ESGVicCEP7g8svwE657yNKQtQx0UXtrjgteJuPjddz_RYf92YIWiUJxpMx_To53E2hXoMQmnpOSc3Jws0L7SAQTH2Qdno9XFlOih236mUlx6AIEhW3Yx'
auth_header = {'Authorization': 'Bearer ' + key}

# We demo the "Business Search" part of the Yelp API
# See https://www.yelp.com/developers/documentation/v3/business_search 
# for documentation
url = 'https://api.yelp.com/v3/businesses/search'

# We search for "Village Taverna in New York"
# Check the documentation for other parameters
parameters = {
    "term": "village taverna",
    "location": "new york, ny",
    "limit": 50
}

# Issue the authenticated request
resp = requests.get(url, headers=auth_header, params=parameters)
data = resp.json()

# %%
data
# Out:
# {'businesses': [{'id': 'ZXiT7FuFAkmjg4pXYxb06A',
#    'alias': 'village-taverna-new-york',
#    'name': 'Village Taverna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UgvNnC3DAd0TXiibbrqx4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/village-taverna-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 283,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73339, 'longitude': -73.99306},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '81 University Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81 University Pl', 'New York, NY 10003']},
#    'phone': '+12129823457',
#    'display_phone': '(212) 982-3457',
#    'distance': 3099.7035782872367},
#   {'id': 'apykLG7DTZ-7xnOcZGDZZA',
#    'alias': 'taverna-kyclades-east-village-new-york-2',
#    'name': 'Taverna Kyclades - East Village',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ekXPwoFyzNsVZ0pKmRXSZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taverna-kyclades-east-village-new-york-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 769,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7310782469639,
#     'longitude': -73.9825163036585},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '228 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 1st Ave', 'New York, NY 10009']},
#    'phone': '+12124320011',
#    'display_phone': '(212) 432-0011',
#    'distance': 3018.164391413235},
#   {'id': '7xV4gzrgaOgQYtPC3FBZig',
#    'alias': 'pylos-new-york',
#    'name': 'Pylos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gQdXP4qPNl1IVCWRcH6M4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pylos-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1087,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72608, 'longitude': -73.98415},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '128 E 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 E 7th St', 'New York, NY 10009']},
#    'phone': '+12124730220',
#    'display_phone': '(212) 473-0220',
#    'distance': 2450.554618974131},
#   {'id': 'MxE0X8ayNGii9zA2i2ZERA',
#    'alias': 'snack-taverna-new-york',
#    'name': 'Snack Taverna',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/as3cDn9pWQbNoQJZEbmVTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snack-taverna-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 314,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.731033, 'longitude': -74.004814},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '63 Bedford St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63 Bedford St', 'New York, NY 10014']},
#    'phone': '+12129293499',
#    'display_phone': '(212) 929-3499',
#    'distance': 2980.3515196916433},
#   {'id': 'enT7NJ7tLMvUMCWQcsUonw',
#    'alias': 'mémé-mediterranean-new-york-4',
#    'name': 'Mémé Mediterranean',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/S_AGzj9dc-vhPPjGKB6BcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/m%C3%A9m%C3%A9-mediterranean-new-york-4?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 560,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.736412, 'longitude': -74.00616},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '581 Hudson St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['581 Hudson St', 'New York, NY 10014']},
#    'phone': '+16466928450',
#    'display_phone': '(646) 692-8450',
#    'distance': 3585.669092216312},
#   {'id': '6gDUVNZo0E9lxO2DkAhHOQ',
#    'alias': 'the-greek-new-york',
#    'name': 'The Greek',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iNDFJbZkzf31l-CIuWFUxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-greek-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 466,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7237145, 'longitude': -74.0096166},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '458 Greenwich St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['458 Greenwich St', 'New York, NY 10013']},
#    'phone': '+16464763941',
#    'display_phone': '(646) 476-3941',
#    'distance': 2407.257084814081},
#   {'id': '_Mpp5d7mjLLZbDFSLx7LVg',
#    'alias': 'e-taverna-to-koutouki-astoria',
#    'name': 'E Taverna To Koutouki',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pZIID6FO6eVTU_l_ks200g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/e-taverna-to-koutouki-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 189,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.776282, 'longitude': -73.915126},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2619 23rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2619 23rd Ave', 'Astoria, NY 11105']},
#    'phone': '+17186066606',
#    'display_phone': '(718) 606-6606',
#    'distance': 10322.35292627355},
#   {'id': '2HZ4UGqSzbb91nWui7VYLg',
#    'alias': 'periyali-new-york',
#    'name': 'Periyali',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p5Y3f6cGiqSGQOpQJFZl9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/periyali-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 250,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7406298582957,
#     'longitude': -73.9929678154494},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '35 W 20th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 W 20th St', 'New York, NY 10011']},
#    'phone': '+12124637890',
#    'display_phone': '(212) 463-7890',
#    'distance': 3913.982486504821},
#   {'id': '_4Grm99JEHnDWskCHAJfUg',
#    'alias': 'kikis-new-york',
#    'name': "Kiki's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GgeWTqIFt1KuRqfcFHDKUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kikis-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 532,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7144971858255,
#     'longitude': -73.9918553931336},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '130 Division St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 Division St', 'New York, NY 10002']},
#    'phone': '+16468827052',
#    'display_phone': '(646) 882-7052',
#    'distance': 1027.330009136556},
#   {'id': 'Rn3Lf7BLoMHul0dEiNtT5Q',
#    'alias': 'ela-taverna-brooklyn',
#    'name': 'Ela Taverna',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/S_WsNGo6QZlfszpKeLgPvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ela-taverna-brooklyn?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 99,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71916, 'longitude': -73.9586},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '98 Berry St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['98 Berry St', 'Brooklyn, NY 11249']},
#    'phone': '+17185991911',
#    'display_phone': '(718) 599-1911',
#    'distance': 3370.4966221270406},
#   {'id': '6CSyG4P-5vicgPIzfXHK7Q',
#    'alias': 'gregorys-26-corner-taverna-astoria',
#    'name': "Gregory's 26 Corner Taverna",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AsLDThQ-Uc1JF-XSSAv8Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gregorys-26-corner-taverna-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 186,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.776263, 'longitude': -73.916025},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2602 23rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2602 23rd Ave', 'Astoria, NY 11105']},
#    'phone': '+17187775511',
#    'display_phone': '(718) 777-5511',
#    'distance': 10282.914376304674},
#   {'id': 'ZD9OPTKRx-BWqXgfqwCy7w',
#    'alias': 'souvlaki-gr-new-york-9',
#    'name': 'Souvlaki GR',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ORtNcVETxR06wJr_wM8Tug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/souvlaki-gr-new-york-9?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 78,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75725, 'longitude': -73.96808},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '231 E 53rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 E 53rd St', 'New York, NY 10022']},
#    'phone': '+12128320395',
#    'display_phone': '(212) 832-0395',
#    'distance': 6172.961659773376},
#   {'id': 'lUpyqsKw-IBqsMgYIHZj7Q',
#    'alias': 'balade-new-york',
#    'name': 'Balade',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ioQDiUhm-Ya_Qfged9Owgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/balade-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 634,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'lebanese', 'title': 'Lebanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730251, 'longitude': -73.983001},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '208 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 1st Ave', 'New York, NY 10009']},
#    'phone': '+12125296868',
#    'display_phone': '(212) 529-6868',
#    'distance': 2919.074046512832},
#   {'id': 'l9b8NbDyhKhnjLKtUwlPwQ',
#    'alias': 'olea-brooklyn-2',
#    'name': 'Olea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1QHMMY7YIQMoXFszPPoDOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olea-brooklyn-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 816,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6877844, 'longitude': -73.9706046},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '171 Lafayette Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['171 Lafayette Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186437003',
#    'display_phone': '(718) 643-7003',
#    'distance': 2797.8774095098875},
#   {'id': 'JEQ00qBAepe0oSiUBdfIew',
#    'alias': 'taverna-kyclades-astoria',
#    'name': 'Taverna Kyclades',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kcsApYF3hR0aO0kX5sU55A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taverna-kyclades-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 2143,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7753227, 'longitude': -73.909217},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3307 Ditmars Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3307 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17185458666',
#    'display_phone': '(718) 545-8666',
#    'distance': 10571.118527927096},
#   {'id': 'wPx4aNffBizdYmCG-WLKpQ',
#    'alias': 'loukoumi-taverna-astoria-2',
#    'name': 'Loukoumi Taverna',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VZ8qUTwyOmCAfRF_EqPYaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loukoumi-taverna-astoria-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 406,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77079, 'longitude': -73.90268},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '45-07 Ditmars Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45-07 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17186263200',
#    'display_phone': '(718) 626-3200',
#    'distance': 10594.455739132025},
#   {'id': 'm8Ytb_3eYIiWla68Lk2fFA',
#    'alias': 'under-the-bridge-new-york',
#    'name': 'Under The Bridge',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YtoybgmZc1H0mbtSj7sldg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/under-the-bridge-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 174,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7596400253254,
#     'longitude': -73.9623098820448},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1079 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1079 1st Ave', 'New York, NY 10022']},
#    'phone': '+12125830695',
#    'display_phone': '(212) 583-0695',
#    'distance': 6601.3479545334385},
#   {'id': '-rqqnZeGmwyfkqoRskSO1g',
#    'alias': 'koroni-souvlaki-and-grill-astoria',
#    'name': 'Koroni Souvlaki and Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PcsV9bmC1OdBFMEm64heaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/koroni-souvlaki-and-grill-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 210,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.768544, 'longitude': -73.92121},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '29-37 Newtown Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29-37 Newtown Ave', 'Astoria, NY 11102']},
#    'phone': '+17184898820',
#    'display_phone': '(718) 489-8820',
#    'distance': 9335.07581240148},
#   {'id': 'kgJwblaytYITxd9KhtqzKA',
#    'alias': 'merakia-new-york-2',
#    'name': 'Merakia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gPYHPv-NYun_jxTAcVdxFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/merakia-new-york-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 135,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74073, 'longitude': -73.99104},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '5 W 21st St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 W 21st St', 'New York, NY 10010']},
#    'phone': '+12123801950',
#    'display_phone': '(212) 380-1950',
#    'distance': 3930.20799975043},
#   {'id': 'rWWRlHOPrIk_7ElfTdU65w',
#    'alias': 'zenon-taverna-astoria',
#    'name': 'Zenon Taverna',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8KWW15oMP9uag2dfXjyxaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zenon-taverna-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 498,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.762819, 'longitude': -73.920872},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3410 31st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3410 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+17189560133',
#    'display_phone': '(718) 956-0133',
#    'distance': 8887.017142245686},
#   {'id': '-fcbr1p0Uijjg3WpDDn5VA',
#    'alias': 'avlee-greek-kitchen-brooklyn-3',
#    'name': 'Avlee Greek Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3lyGsZgxN8afbc1RpIxzrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avlee-greek-kitchen-brooklyn-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 240,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.679911, 'longitude': -73.994879},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '349 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['349 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+17188555125',
#    'display_phone': '(718) 855-5125',
#    'distance': 2839.6625442656896},
#   {'id': 'gG0pitVnSaUMGbEL3boF0g',
#    'alias': 'souvlaki-gr-new-york-3',
#    'name': 'Souvlaki GR',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RQeKeMZyIUwr_DaPunT2kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/souvlaki-gr-new-york-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 836,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72122, 'longitude': -73.98711},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '116 Stanton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['116 Stanton St', 'New York, NY 10002']},
#    'phone': '+12127770116',
#    'display_phone': '(212) 777-0116',
#    'distance': 1856.2069870201426},
#   {'id': '62dhOUChlqsVkszPxqwq9Q',
#    'alias': 'stamatis-restaurant-astoria',
#    'name': 'Stamatis Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rosEdqaJgpHZTTDL-PnQxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stamatis-restaurant-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 377,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7750206, 'longitude': -73.9133301},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2909 23rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2909 23rd Ave', 'Astoria, NY 11105']},
#    'phone': '+17189328596',
#    'display_phone': '(718) 932-8596',
#    'distance': 10315.102319973523},
#   {'id': '6KzJ3JEOQ4QrVbrrRtBxQw',
#    'alias': 'avli-the-little-greek-tavern-bayside-3',
#    'name': 'Avli The Little Greek Tavern',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kadjfKUEuS660Plp97zkEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avli-the-little-greek-tavern-bayside-3?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 759,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7656432, 'longitude': -73.7718683},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '38-31 Bell Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38-31 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17182247575',
#    'display_phone': '(718) 224-7575',
#    'distance': 19905.019413800037},
#   {'id': 'YYMbXek5-Upj0g3RAjuI7A',
#    'alias': 'ousia-new-york',
#    'name': 'Ousia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-_FJtVhsKbSoc8t53KTYDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ousia-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 191,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7707946574904,
#     'longitude': -73.992433445755},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '629 W 57th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['629 W 57th St', 'New York, NY 10019']},
#    'phone': '+12123332000',
#    'display_phone': '(212) 333-2000',
#    'distance': 7268.246548097867},
#   {'id': 'Nj20jEI5OB813dBdSk8WOA',
#    'alias': 'elia-taverna-bronxville',
#    'name': 'Elia Taverna',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/evl2bJoeEibEmm0LCuvB3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elia-taverna-bronxville?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 188,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.928312, 'longitude': -73.80863},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '502 New Rochelle Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronxville',
#     'zip_code': '10708',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['502 New Rochelle Rd', 'Bronxville, NY 10708']},
#    'phone': '+19146634976',
#    'display_phone': '(914) 663-4976',
#    'distance': 29295.73535886023},
#   {'id': 'dT4fl34s1MQaLQARc5BSFw',
#    'alias': 'agora-taverna-forest-hills-2',
#    'name': 'Agora Taverna',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6bC0dOXPRM64D1p1MHnSvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/agora-taverna-forest-hills-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 568,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.721009372316, 'longitude': -73.846807820392},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '70-09 Austin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70-09 Austin St', 'Forest Hills, NY 11375']},
#    'phone': '+17187937300',
#    'display_phone': '(718) 793-7300',
#    'distance': 12550.538245244432},
#   {'id': 'aP3Z0DXzwzM8lZWg3YX9KQ',
#    'alias': 'molyvos-new-york',
#    'name': 'Molyvos',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZTHVInVox-Z02Kenz0V9Ug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/molyvos-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 477,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7644338, 'longitude': -73.9806394},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '871 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['871 7th Ave', 'New York, NY 10019']},
#    'phone': '+12125827500',
#    'display_phone': '(212) 582-7500',
#    'distance': 6659.384321371647},
#   {'id': '5Rp1SRrMhNlXeMLUxhASoQ',
#    'alias': 'opa-souvlaki-astoria',
#    'name': 'Opa Souvlaki',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/exiVfIbThAr-2_9DZtT6Zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/opa-souvlaki-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 229,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76753, 'longitude': -73.92125},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '28-44 31st St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28-44 31st St', 'Astoria, NY 11102']},
#    'phone': '+17187283638',
#    'display_phone': '(718) 728-3638',
#    'distance': 9248.828785696533},
#   {'id': 'oY-tooKEm8F-6Il1JOQzKg',
#    'alias': 'souvlaki-gr-new-york-6',
#    'name': 'Souvlaki GR',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/D6msLu_7sF9qa1xos-msGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/souvlaki-gr-new-york-6?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 550,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76465, 'longitude': -73.98029},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '162 W 56th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 W 56th St', 'New York, NY 10019']},
#    'phone': '+12129747482',
#    'display_phone': '(212) 974-7482',
#    'distance': 6683.919027849633},
#   {'id': 'XDL8GWy3uCB8bdpMiRLRJw',
#    'alias': 'agnanti-astoria',
#    'name': 'Agnanti',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lZPjYZUU8b6hRl7ttaL73A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/agnanti-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 427,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7809792, 'longitude': -73.9179077},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '19-06 Ditmars Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19-06 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17185454554',
#    'display_phone': '(718) 545-4554',
#    'distance': 10582.803266898442},
#   {'id': 'Bn1mZhb501Tvf7_-Pfi9_g',
#    'alias': 'korali-estiatorio-new-york',
#    'name': 'Korali Estiatorio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JEWJ-N9Wpl1bSBZ59hmHJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/korali-estiatorio-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 183,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78349, 'longitude': -73.95098},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '1662 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1662 3rd Ave', 'New York, NY 10128']},
#    'phone': '+16469645470',
#    'display_phone': '(646) 964-5470',
#    'distance': 9414.430074483178},
#   {'id': 'wtfEOjfOWVuugf-SuCC5yA',
#    'alias': 'avra-madison-new-york',
#    'name': 'Avra Madison',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Y98xplep2znPUcS-l1fztA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avra-madison-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 223,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7644, 'longitude': -73.97166},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '14 E 60th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 E 60th St', 'New York, NY 10022']},
#    'phone': '+12129370100',
#    'display_phone': '(212) 937-0100',
#    'distance': 6817.115811006596},
#   {'id': 'GeoR6dpTUEpdIoyAd68Irg',
#    'alias': 'kyma-new-york',
#    'name': 'Kyma',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jXkEHCZ_ubs3ISWW-VWVXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kyma-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 82,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73904, 'longitude': -73.99283},
#    'transactions': [],
#    'location': {'address1': '15 W 18th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 W 18th St', 'New York, NY 10011']},
#    'phone': '+12122685555',
#    'display_phone': '(212) 268-5555',
#    'distance': 3748.6220938396277},
#   {'id': 'blXVGUTB-4epYW9KFsQJ_g',
#    'alias': 'the-greek-kitchen-new-york',
#    'name': 'The Greek Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LfiA1jUqKExxteN7f9FkuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-greek-kitchen-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 463,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7697614, 'longitude': -73.9881055},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '889 10th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['889 10th Ave', 'New York, NY 10019']},
#    'phone': '+12125814303',
#    'display_phone': '(212) 581-4303',
#    'distance': 7170.641098602993},
#   {'id': 'trEnFaHqRkJqtjRvzx7PsQ',
#    'alias': 'dafni-greek-taverna-new-york',
#    'name': 'Dafni Greek Taverna',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cMbLmxxlG_u5TjKgxIQ3Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dafni-greek-taverna-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 915,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75788, 'longitude': -73.99092},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '325 West 42nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['325 West 42nd St', 'New York, NY 10036']},
#    'phone': '+12123151010',
#    'display_phone': '(212) 315-1010',
#    'distance': 5851.479278714366},
#   {'id': '1SaKutXcH38X0KvayyDHUA',
#    'alias': 'barbounia-new-york',
#    'name': 'Barbounia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Yg2j6z3ayWLv-H5BycggPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barbounia-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 1194,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7382, 'longitude': -73.98804},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '250 Park Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['250 Park Ave S', 'New York, NY 10003']},
#    'phone': '+12129950242',
#    'display_phone': '(212) 995-0242',
#    'distance': 3684.893443877367},
#   {'id': 'fJhzNx7t2QybrYudxULGoA',
#    'alias': 'marias-mediterranean-bayside',
#    'name': "Maria's Mediterranean",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/546cW1ju1k5S2SF39c9DDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marias-mediterranean-bayside?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 333,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7661182, 'longitude': -73.7721149},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '38-11 Bell Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38-11 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17182791606',
#    'display_phone': '(718) 279-1606',
#    'distance': 19893.259249075116},
#   {'id': 'JIWCAWQnRVevwhbyADcLgg',
#    'alias': 'meze-brooklyn-2',
#    'name': 'Meze',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hMMRf544GMPSZ9oUJdqhjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meze-brooklyn-2?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 291,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.62523, 'longitude': -74.00211},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '6601 13th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11219',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6601 13th Ave', 'Brooklyn, NY 11219']},
#    'phone': '+17182346393',
#    'display_phone': '(718) 234-6393',
#    'distance': 8949.272440642862},
#   {'id': 'RgEtvACRayQhRPnEs_kkIw',
#    'alias': 'ethos-gallery-51st-new-york',
#    'name': 'Ethos Gallery 51st',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OH8pef_q0i-quFp7MzU0jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ethos-gallery-51st-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 423,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7545262, 'longitude': -73.9660484},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '905 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['905 1st Ave', 'New York, NY 10022']},
#    'phone': '+12128884060',
#    'display_phone': '(212) 888-4060',
#    'distance': 5953.9565040108355},
#   {'id': 'Ey29dYV1gAtalkwPH8k1vg',
#    'alias': 'taverna-kyclades-bayside-bayside',
#    'name': 'Taverna Kyclades - Bayside',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YKiol-htdq_z2pwNmjHWDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taverna-kyclades-bayside-bayside?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 225,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76446, 'longitude': -73.77174},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '39-28 Bell Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-28 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17186312000',
#    'display_phone': '(718) 631-2000',
#    'distance': 19866.17107329118},
#   {'id': 'mhhTORjUdXj-UIDjyGmhBg',
#    'alias': 'estiatorio-milos-new-york',
#    'name': 'Estiatorio Milos',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MHD33qCbDYiAqSjW592B6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/estiatorio-milos-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 838,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76368, 'longitude': -73.97922},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '125 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['125 W 55th St', 'New York, NY 10019']},
#    'phone': '+12122457400',
#    'display_phone': '(212) 245-7400',
#    'distance': 6594.264983129335},
#   {'id': 'K0UNoqk1PczdaiZfoMRbEA',
#    'alias': 'greek-express-bronx',
#    'name': 'Greek Express',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mkG8Ss0GjQLB6JqzRgfBXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greek-express-bronx?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 217,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8875, 'longitude': -73.9076},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3733 Riverdale Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10463',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3733 Riverdale Ave', 'Bronx, NY 10463']},
#    'phone': '+17186014976',
#    'display_phone': '(718) 601-4976',
#    'distance': 21517.466939147675},
#   {'id': 'BdqOP7iyhE14RM2onuFd4w',
#    'alias': 'nikitas-place-whitestone',
#    'name': 'Nikitas Place',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/L9IDVtDDh7FMoxstIIvYSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nikitas-place-whitestone?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 70,
#    'categories': [{'alias': 'greek', 'title': 'Greek'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7803077, 'longitude': -73.7937545},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1903 Utopia Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1903 Utopia Pkwy', 'Whitestone, NY 11357']},
#    'phone': '+17184284976',
#    'display_phone': '(718) 428-4976',
#    'distance': 18845.79230118722},
#   {'id': 'F89nDDlYZ7wbRe8EpLCqBw',
#    'alias': 'avra-estiatorio-new-york',
#    'name': 'Avra Estiatorio',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9z9aAStTyB0fKj-dIUvNZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avra-estiatorio-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 810,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75513, 'longitude': -73.97245},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '141 E 48th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['141 E 48th St', 'New York, NY 10017']},
#    'phone': '+12127598550',
#    'display_phone': '(212) 759-8550',
#    'distance': 5816.957246173547},
#   {'id': 'H87m0azdhuw5uo6Y166uUg',
#    'alias': 'loi-estiatorio-new-york',
#    'name': 'Loi Estiatorio',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_IkbdruHkOpBBA8Oy5Ub1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loi-estiatorio-new-york?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 322,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.765385, 'longitude': -73.978002},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '132 W 58th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 W 58th St', 'New York, NY 10019']},
#    'phone': '+12127130015',
#    'display_phone': '(212) 713-0015',
#    'distance': 6804.9066611968565},
#   {'id': 'ApbLKC5c3xoYn5XOJ85Y3g',
#    'alias': 'aliada-restaurant-astoria',
#    'name': 'Aliada Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mnjXfAeFCNf3pekksvuBJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aliada-restaurant-astoria?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 354,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7626, 'longitude': -73.92616},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '29-19 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29-19 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17189322240',
#    'display_phone': '(718) 932-2240',
#    'distance': 8559.409612852241},
#   {'id': 'd5i5NvBcah7zX0Z5nK5BHA',
#    'alias': 'faros-restaurant-brooklyn-4',
#    'name': 'Faros Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XJC15_1jOfvVyAJ906q81Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/faros-restaurant-brooklyn-4?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 196,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6749, 'longitude': -73.97532},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '84 7th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 7th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17186232767',
#    'display_phone': '(718) 623-2767',
#    'distance': 3748.568098966837},
#   {'id': 'ift35m5Sbya_3ZWnDo84tA',
#    'alias': 'kuzina-staten-island-7',
#    'name': 'Kuzina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9Q7w77nWIjRG8qX7_3YHvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kuzina-staten-island-7?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 97,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.592724, 'longitude': -74.0868},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1458 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1458 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189804744',
#    'display_phone': '(718) 980-4744',
#    'distance': 14765.09707307215},
#   {'id': 'cxvndpb_DjtZaeBj6Ed81A',
#    'alias': 'ammos-estiatorio-new-york-4',
#    'name': 'Ammos Estiatorio',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6mHA6EPC_5F9J6IRZusOUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ammos-estiatorio-new-york-4?adjust_creative=5_w7gXS2q4oZneGWloS_3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5_w7gXS2q4oZneGWloS_3Q',
#    'review_count': 247,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.75426, 'longitude': -73.97733},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '52 Vanderbilt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 Vanderbilt Ave', 'New York, NY 10017']},
#    'phone': '+12129229999',
#    'display_phone': '(212) 922-9999',
#    'distance': 5620.478527487063}],
#  'total': 82,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
# We get back the answer. It contains three keys
# The main one is the "business", which contains a list of the results
data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
# We can put the results directly into a dataframe
# The issue is that some columns (e.g location) are composite and
# instead of containing values, the cells contain *dictionaries*
import pandas as pd
df = pd.DataFrame(data['businesses'])
df.head(5)
# Out:
#                                       alias  \
# 0                  village-taverna-new-york
# 1  taverna-kyclades-east-village-new-york-2
# 2                            pylos-new-york
# 3                    snack-taverna-new-york
# 4             mémé-mediterranean-new-york-4
#
#                                           categories  \
# 0  [{'alias': 'greek', 'title': 'Greek'}, {'alias...
# 1  [{'alias': 'greek', 'title': 'Greek'}, {'alias...
# 2             [{'alias': 'greek', 'title': 'Greek'}]
# 3  [{'alias': 'greek', 'title': 'Greek'}, {'alias...
# 4  [{'alias': 'mediterranean', 'title': 'Mediterr...
#
#                                          coordinates   display_phone  \
# 0     {'latitude': 40.73339, 'longitude': -73.99306}  (212) 982-3457
# 1  {'latitude': 40.7310782469639, 'longitude': -7...  (212) 432-0011
# 2     {'latitude': 40.72608, 'longitude': -73.98415}  (212) 473-0220
# 3   {'latitude': 40.731033, 'longitude': -74.004814}  (212) 929-3499
# 4    {'latitude': 40.736412, 'longitude': -74.00616}  (646) 692-8450
#
#       distance                      id  \
# 0  3099.703578  ZXiT7FuFAkmjg4pXYxb06A
# 1  3018.164391  apykLG7DTZ-7xnOcZGDZZA
# 2  2450.554619  7xV4gzrgaOgQYtPC3FBZig
# 3  2980.351520  MxE0X8ayNGii9zA2i2ZERA
# 4  3585.669092  enT7NJ7tLMvUMCWQcsUonw
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/UgvNnC...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/ekXPwo...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/gQdXP4...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/as3cDn...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/S_AGzj...      False
#
#                                             location  \
# 0  {'address1': '81 University Pl', 'address2': '...
# 1  {'address1': '228 1st Ave', 'address2': '', 'a...
# 2  {'address1': '128 E 7th St', 'address2': None,...
# 3  {'address1': '63 Bedford St', 'address2': '', ...
# 4  {'address1': '581 Hudson St', 'address2': '', ...
#
#                               name         phone price  rating  review_count  \
# 0                  Village Taverna  +12129823457    $$     3.5           283
# 1  Taverna Kyclades - East Village  +12124320011    $$     4.0           769
# 2                            Pylos  +12124730220   $$$     4.5          1087
# 3                    Snack Taverna  +12129293499    $$     4.0           314
# 4               Mémé Mediterranean  +16466928450    $$     4.0           560
#
#          transactions                                                url
# 0  [pickup, delivery]  https://www.yelp.com/biz/village-taverna-new-y...
# 1                  []  https://www.yelp.com/biz/taverna-kyclades-east...
# 2  [pickup, delivery]  https://www.yelp.com/biz/pylos-new-york?adjust...
# 3  [pickup, delivery]  https://www.yelp.com/biz/snack-taverna-new-yor...
# 4                  []  https://www.yelp.com/biz/m%C3%A9m%C3%A9-medite...

# %%
# In principle, the json_normalize command should be 
# able to parse the JSON response and create a dataframe
# http://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.io.json.json_normalize.html

# For some reason (to be debugged) it does not work.

# %%
import pandas as pd
df = pd.DataFrame(data['businesses'])

# We take the dictionaries in the location and coordinates columns
# and create new dataframes for both of them, with each element of the dictionary
# now being a column
address_df = df.location.apply(pd.Series)
coordinates_df = df.coordinates.apply(pd.Series)

# We remove location and coordinates from the original dataframe
df.drop('location', axis='columns', inplace=True)
df.drop('coordinates', axis='columns', inplace=True)

# We also drop columns that we do not need
df.drop('categories', axis='columns', inplace=True)
df.drop('transactions', axis='columns', inplace=True)
df.drop('image_url', axis='columns', inplace=True)

# Put together the original dataframe, the addresses, and the coordinates dataframes
# (We concatenate the 3 dataframes bu putting them all next to each other)
new_df = pd.concat([df, address_df, coordinates_df], axis='columns')
new_df
# Out:
#                                        alias   display_phone      distance  \
# 0                   village-taverna-new-york  (212) 982-3457   3099.703578
# 1   taverna-kyclades-east-village-new-york-2  (212) 432-0011   3018.164391
# 2                             pylos-new-york  (212) 473-0220   2450.554619
# 3                     snack-taverna-new-york  (212) 929-3499   2980.351520
# 4              mémé-mediterranean-new-york-4  (646) 692-8450   3585.669092
# 5                         the-greek-new-york  (646) 476-3941   2407.257085
# 6              e-taverna-to-koutouki-astoria  (718) 606-6606  10322.352926
# 44  F89nDDlYZ7wbRe8EpLCqBw      False                  Avra Estiatorio
# 45  H87m0azdhuw5uo6Y166uUg      False                   Loi Estiatorio
# 46  ApbLKC5c3xoYn5XOJ85Y3g      False                Aliada Restaurant
# 47  d5i5NvBcah7zX0Z5nK5BHA      False                 Faros Restaurant
# 48  ift35m5Sbya_3ZWnDo84tA      False                           Kuzina
# 49  cxvndpb_DjtZaeBj6Ed81A      False                 Ammos Estiatorio
#
#            phone price  rating  review_count    ...                 address1  \
# 0   +12129823457    $$     3.5           283    ...         81 University Pl
# 1   +12124320011    $$     4.0           769    ...              228 1st Ave
# 2   +12124730220   $$$     4.5          1087    ...             128 E 7th St
# 3   +12129293499    $$     4.0           314    ...            63 Bedford St
# 4   +16466928450    $$     4.0           560    ...            581 Hudson St
# 5   +16464763941   $$$     4.5           466    ...         458 Greenwich St
# 6   +17186066606    $$     4.5           189    ...            2619 23rd Ave
# 7   +12124637890   $$$     4.0           250    ...             35 W 20th St
# 8   +16468827052    $$     4.0           532    ...          130 Division St
# 9   +17185991911    $$     4.0            99    ...              98 Berry St
# 10  +17187775511    $$     4.0           186    ...            2602 23rd Ave
# 11  +12128320395    $$     4.5            78    ...            231 E 53rd St
# 12  +12125296868    $$     4.0           634    ...              208 1st Ave
# 13  +17186437003    $$     4.0           816    ...        171 Lafayette Ave
# 14  +17185458666    $$     4.0          2143    ...        3307 Ditmars Blvd
# 15  +17186263200    $$     4.5           406    ...       45-07 Ditmars Blvd
# 16  +12125830695    $$     4.0           174    ...             1079 1st Ave
# 17  +17184898820    $$     5.0           210    ...        29-37 Newtown Ave
# 18  +12123801950   $$$     4.0           135    ...              5 W 21st St
# 19  +17189560133    $$     4.0           498    ...            3410 31st Ave
# 20  +17188555125    $$     4.5           240    ...             349 Smith St
# 21  +12127770116    $$     4.0           836    ...           116 Stanton St
# 22  +17189328596    $$     4.0           377    ...            2909 23rd Ave
# 23  +17182247575    $$     4.0           759    ...          38-31 Bell Blvd
# 24  +12123332000   $$$     4.0           191    ...            629 W 57th St
# 25  +19146634976    $$     4.0           188    ...      502 New Rochelle Rd
# 26  +17187937300    $$     3.5           568    ...          70-09 Austin St
# 27  +12125827500   $$$     3.5           477    ...              871 7th Ave
# 28  +17187283638    $$     3.5           229    ...            28-44 31st St
# 29  +12129747482    $$     4.0           550    ...            162 W 56th St
# 30  +17185454554    $$     3.5           427    ...       19-06 Ditmars Blvd
# 31  +16469645470   $$$     4.0           183    ...             1662 3rd Ave
# 32  +12129370100   $$$     4.0           223    ...             14 E 60th St
# 33  +12122685555   NaN     3.5            82    ...             15 W 18th St
# 34  +12125814303    $$     4.0           463    ...             889 10th Ave
# 35  +12123151010    $$     4.0           915    ...         325 West 42nd St
# 36  +12129950242   $$$     3.5          1194    ...           250 Park Ave S
# 37  +17182791606    $$     4.0           333    ...          38-11 Bell Blvd
# 38  +17182346393    $$     4.0           291    ...            6601 13th Ave
# 39  +12128884060   $$$     3.5           423    ...              905 1st Ave
# 40  +17186312000    $$     4.0           225    ...          39-28 Bell Blvd
# 41  +12122457400  $$$$     4.0           838    ...            125 W 55th St
# 42  +17186014976    $$     4.0           217    ...       3733 Riverdale Ave
# 43  +17184284976    $$     3.5            70    ...         1903 Utopia Pkwy
# 44  +12127598550   $$$     4.0           810    ...            141 E 48th St
# 45  +12127130015   $$$     4.5           322    ...            132 W 58th St
# 46  +17189322240    $$     4.0           354    ...           29-19 Broadway
# 47  +17186232767    $$     4.0           196    ...               84 7th Ave
# 48  +17189804744    $$     4.0            97    ...          1458 Hylan Blvd
# 49  +12129229999   $$$     3.0           247    ...        52 Vanderbilt Ave
#
#    address2 address3           city zip_code country state  \
# 0                          New York    10003      US    NY
# 1                          New York    10009      US    NY
# 2      None                New York    10009      US    NY
# 3                          New York    10014      US    NY
# 4                          New York    10014      US    NY
# 5                          New York    10013      US    NY
# 6                           Astoria    11105      US    NY
# 7                          New York    10011      US    NY
# 8                          New York    10002      US    NY
# 9               None       Brooklyn    11249      US    NY
# 10                          Astoria    11105      US    NY
# 11              None       New York    10022      US    NY
# 12                         New York    10009      US    NY
# 13                         Brooklyn    11238      US    NY
# 14                          Astoria    11105      US    NY
# 15                          Astoria    11105      US    NY
# 16                         New York    10022      US    NY
# 17              None        Astoria    11102      US    NY
# 18     None                New York    10010      US    NY
# 19                          Astoria    11106      US    NY
# 20                         Brooklyn    11231      US    NY
# 21                         New York    10002      US    NY
# 22                          Astoria    11105      US    NY
# 23                          Bayside    11361      US    NY
# 24     None                New York    10019      US    NY
# 25                       Bronxville    10708      US    NY
# 26                     Forest Hills    11375      US    NY
# 27                         New York    10019      US    NY
# 28                          Astoria    11102      US    NY
# 29     None                New York    10019      US    NY
# 30                          Astoria    11105      US    NY
# 31                         New York    10128      US    NY
# 32              None       New York    10022      US    NY
# 33              None       New York    10011      US    NY
# 34                         New York    10019      US    NY
# 35     None                New York    10036      US    NY
# 36                         New York    10003      US    NY
# 37     None                 Bayside    11361      US    NY
# 38                         Brooklyn    11219      US    NY
# 39                         New York    10022      US    NY
# 40              None        Bayside    11361      US    NY
# 41                         New York    10019      US    NY
# 42                            Bronx    10463      US    NY
# 43                       Whitestone    11357      US    NY
# 44                         New York    10017      US    NY
# 45                         New York    10019      US    NY
# 46                          Astoria    11106      US    NY
# 47                         Brooklyn    11217      US    NY
# 48                    Staten Island    10305      US    NY
# 49                         New York    10017      US    NY
#
#                                 display_address   latitude  longitude
# 0        [81 University Pl, New York, NY 10003]  40.733390 -73.993060
# 1             [228 1st Ave, New York, NY 10009]  40.731078 -73.982516
# 2            [128 E 7th St, New York, NY 10009]  40.726080 -73.984150
# 3           [63 Bedford St, New York, NY 10014]  40.731033 -74.004814
# 4           [581 Hudson St, New York, NY 10014]  40.736412 -74.006160
# 5        [458 Greenwich St, New York, NY 10013]  40.723714 -74.009617
# 6            [2619 23rd Ave, Astoria, NY 11105]  40.776282 -73.915126
# 7            [35 W 20th St, New York, NY 10011]  40.740630 -73.992968
# 8         [130 Division St, New York, NY 10002]  40.714497 -73.991855
